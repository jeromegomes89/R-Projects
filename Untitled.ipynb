# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd() # Current working directory
# Out:
# 'C:\\Users\\Jerome.gomes'

# %%
os.chdir("C:\\Users\\Jerome.gomes\\Desktop\\New folder\\PandasEssentialTraining\\data") # change working directory

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jerome.gomes\\Desktop\\New folder\\PandasEssentialTraining\\data'

# %%
os.listdir() # See the list of files in the working directory
# Out:
# ['olympics.csv',
#  'Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv']

# %%
oo = pd.read_csv('olympics.csv', skiprows = 4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.dtypes
# Out:
# City            object
# Edition          int64
# Sport           object
# Discipline      object
# Athlete         object
# NOC             object
# Gender          object
# Event           object
# Event_gender    object
# Medal           object
# dtype: object

# %% [markdown]
# A series ois a one dimentional array of indexed data.
# Accessing a single series : Dataframe['Series Name'] OR Dataframe["Series Name"] OR Dataframe.Series Name
# Accessing a multiple series : Dataframe[['Series Name1','Series Name2']]

# %%
type(oo) # type(DataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(oo.Edition) # type(DataFrame.Series)
# Out:
# pandas.core.series.Series

# %%
type(oo[['City','Edition','Medal']]) # type(DataFrame[['Series1','Series2']])
# Out:
# pandas.core.frame.DataFrame

# %%
## Accessing Series
oo.City.head()
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3    Athens
# 4    Athens
# Name: City, dtype: object

# %%
oo['NOC'] # OR oo.NOC (dot notation can be used only when there are no spaces in the column name)
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo[['City','Edition','Medal']]
# Out:
#           City  Edition   Medal
# 0       Athens     1896    Gold
# 1       Athens     1896  Silver
# 2       Athens     1896  Bronze
# 3       Athens     1896    Gold
# 4       Athens     1896  Silver
# 5       Athens     1896  Bronze
# 6       Athens     1896    Gold
# 7       Athens     1896  Silver
# 8       Athens     1896  Bronze
# 9       Athens     1896    Gold
# 10      Athens     1896  Silver
# 11      Athens     1896  Bronze
# 12      Athens     1896  Bronze
# 13      Athens     1896    Gold
# 14      Athens     1896  Silver
# 15      Athens     1896    Gold
# 16      Athens     1896  Silver
# 17      Athens     1896  Bronze
# 18      Athens     1896    Gold
# 19      Athens     1896  Silver
# 20      Athens     1896  Bronze
# 21      Athens     1896    Gold
# 22      Athens     1896  Silver
# 23      Athens     1896  Bronze
# 24      Athens     1896    Gold
# 25      Athens     1896  Silver
# 26      Athens     1896  Bronze
# 27      Athens     1896    Gold
# ...

# %%
pd.read_csv # shit + tab to see documentation of the function

# %%
oo.shape # dimentions of the database
# Out:
# (29216, 10)

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# #### Value Counts ####
# Series.value_counts(nomalize=False,sort=True,ascending=False,bins=None,dropna=True)

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts(ascending=True)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# #### Sort Values ####
# Series.sort_values(by, axis=0,ascending=True, inplace=False, kind='quicksort', na_position = 'last')

# %%
oo.Athlete.sort_values()
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
oo.sort_values(by=['Athlete','Edition'])
# Out:
#                         City  Edition              Sport       Discipline  \
# 651                    Paris     1900         Tug of War       Tug of War
# 2849                 Antwerp     1920           Aquatics         Swimming
# 2852                 Antwerp     1920           Aquatics         Swimming
# 7709                  London     1948         Gymnastics      Artistic G.
# 7716                  London     1948         Gymnastics      Artistic G.
# 7730                  London     1948         Gymnastics      Artistic G.
# 7773                  London     1948         Gymnastics      Artistic G.
# 8563                Helsinki     1952         Gymnastics      Artistic G.
# 28460                Beijing     2008           Handball         Handball
# 3436                 Antwerp     1920         Gymnastics      Artistic G.
# 19062                  Seoul     1988             Hockey           Hockey
# 22769                Atlanta     1996             Rowing           Rowing
# ...

# %% [markdown]
# #### Boolean Indexing ####
# AND - &
# OR - |
# NOT = ~
# multiple conditions must be grouped using brackets

# %%
oo[oo.Medal == "Gold"]
# Out:
#           City  Edition          Sport       Discipline  \
# 0       Athens     1896       Aquatics         Swimming
# 3       Athens     1896       Aquatics         Swimming
# 6       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 13      Athens     1896      Athletics        Athletics
# 15      Athens     1896      Athletics        Athletics
# 18      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 24      Athens     1896      Athletics        Athletics
# 27      Athens     1896      Athletics        Athletics
# 29      Athens     1896      Athletics        Athletics
# 33      Athens     1896      Athletics        Athletics
# 36      Athens     1896      Athletics        Athletics
# 40      Athens     1896      Athletics        Athletics
# 43      Athens     1896      Athletics        Athletics
# 46      Athens     1896      Athletics        Athletics
# ...

# %%
oo[(oo.Medal == "Gold") & (oo.Gender == "Women")]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %% [markdown]
# #### String Handling ####
# This function is available to avery Series using the "str" attribute
# Series.str

# %%
oo.Athlete.str.contains('Florence')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 29186    False
# 29187    False
# 29188    False
# 29189    False
# 29190    False
# 29191    False
# 29192    False
# 29193    False
# 29194    False
# 29195    False
# 29196    False
# 29197    False
# 29198    False
# 29199    False
# 29200    False
# 29201    False
# 29202    False
# 29203    False
# 29204    False
# 29205    False
# 29206    False
# 29207    False
# 29208    False
# 29209    False
# 29210    False
# 29211    False
# 29212    False
# ...

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
# In Which events sis 'Jesse Owens' win a medal
jo = oo[oo.Athlete == 'OWENS, Jesse']

# %%
jo.Event.value_counts()
# Out:
# 200m            1
# long jump       1
# 100m            1
# 4x100m relay    1
# Name: Event, dtype: int64
